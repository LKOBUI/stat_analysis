# %% [markdown]
# ### Table of Contents
#
# 1. loc Method
# 2. Dropping Entries from an Axis
# 3. iloc Method
# 4. Map Functions
# 5. Descriptive and summary statistics
# 6. sorting in pandas
#    - Sort by Index
#    - Sort by values
# 7. Correlation and Covariance
# 8. Unique Values, Value Counts, and Membership
# 9. Handling Missing Data
# 10. Data Cleaning
# 11. Filling In Missing Data
# 12. remove duplicate
# 13. Replacing Values
# 14. Detecting and Filtering Outliers
# 15. Computing Indicator/Dummy Variables
# 16. built-in string methods
# 15. Combining and Merging Datasets
# 16. pivot() in Pandas: What It Does
# 17. Aggregation
