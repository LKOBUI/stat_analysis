# %% [markdown]
# Newton's method - explained:
#
# -	https://www.youtube.com/watch?v=si1geFmH60s
#
# The Gauss Newton Method
#
# -	https://www.youtube.com/watch?v=C6DCtQjKkdY&t=16s
#
# Gradient descent - with a simple example
#
# -	https://www.youtube.com/watch?v=31w-xQX0Z_8
