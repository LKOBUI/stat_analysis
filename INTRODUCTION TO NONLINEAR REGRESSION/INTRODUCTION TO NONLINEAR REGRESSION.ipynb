# %% [markdown]
# ### INTRODUCTION TO NONLINEAR REGRESSION
#
# There are many problems in engineering and the sciences where the response variable and the predictor variables are related through a known nonlinear function. This leads to a nonlinear regression model. When the method of least squares is applied to such models, the resulting normal equations are nonlinear and, in general, difficult to solve. The usual approach is to directly minimize the residual sum of squares by an iterative procedure.
#
# ### 12.1 LINEAR AND NONLINEAR REGRESSION MODELS
#
# ### Qus: how to convert non-linear eqn to linear eqn?
#
# General linear regression model
#
# ![image.png](attachment:image.png)
#
# Zi represents any function of the original regressors x1, x2,…,
#
# xk, including transformations such as exp(xi),√(x_i ) , and sin(xi).
#
# These models are called linear regression models because they are that the diagonal elements of the , the βj, j = 1, 2,…, k.
#
# ![image-2.png](attachment:image-2.png)
#
# ### Qus: Define non-linear regressions models?
#
# Any model that is not linear in the unknown parameters is a nonlinear regression model.
#
# ![image-3.png](attachment:image-3.png)
#
# Above model is not linear in the unknown parameters θ1 and θ2. Where θ to represent a parameter in a nonlinear model Nonlinear regression model:
#
# ![image-4.png](attachment:image-4.png)
#
# call f (x, θ) the expectation function for the nonlinear regression model. similar to the linear regression case, except that now the expectation function is a nonlinear function of the parameters
#
# ### Qus: What is difference between first derivative of linear and nonlinear models?
# Let Linear modes is
#
# ![image-5.png](attachment:image-5.png)
#
# ![image-6.png](attachment:image-6.png)
#
# ## NONLINEAR LEAST SQUARES
#
# #### Qus: What is normal eqn in lest square and how to obtained?
#
# ![image-7.png](attachment:image-7.png)
#
# In least squares method in linear regression involves minimizing the least-squares function
#
# ![image-8.png](attachment:image-8.png)
#
# differentiate S(β) with respect to the unknown parameters and equate the derivatives to zero, the resulting normal equations are linear equations
#
# ![image-9.png](attachment:image-9.png)
# ![image-10.png](attachment:image-10.png)
#
# ### Qus: Write normal eqn of least square of non-linear functions?
#
# least-squares estimates we must differentiate above Eqn with respect to each element of θ. This will provide a set of p normal equations for the nonlinear regression situation. The normal equations are
#
# ![image-11.png](attachment:image-11.png)
#
# Expectation function is also a nonlinear function, so the normal equations can be very difficult to solve.
# Now see normal eqn of non-linear models
#
# Let modles
#
# ![image-12.png](attachment:image-12.png)
#
# least-squares normal equations for this model are
#
# ![image-13.png](attachment:image-13.png)
# ![image-14.png](attachment:image-14.png)
#
# ### Contour Plot for Linear and non-linear models:
#
# ![image-15.png](attachment:image-15.png)
#
# ### Please verify and deep understand this theory:
#
# ### Finding least squares solutions in the nonlinear case:
#
# ### Problem with nonlinear Models to global minimum for θ:
#
# For nonlinear model surface will be very **elongated** near the **optimum**, so **many solutions for θ** will produce a **residual sum of squares** that is **close to the global minimum**. This results in a problem that is **ill-conditioned**,and in such problems it is often difficult to find the global minimum for **θ**. In some situations, the contours may be so irregular that there are several local minima and perhaps more than one global minimum.
#
# ### Qus: Can we use LLM ?
#
# Maximum-Likelihood Estimation We have concentrated on least squares in the nonlinear case. If the error terms in the model are normally and independently distributed with constant variance, application of the method of maximum likelihood to the estimation problem will lead to least squares. See below how possible
#
# ![image-16.png](attachment:image-16.png)
#
# ### 12.4 TRANFORMATION TO A LINEAR MODEL
#
# ![image-17.png](attachment:image-17.png)
#
# Please Solve this Example 12.4 The Puromycin Data by using Lest square method
#
# ### 12.5 PARAMETER ESTIMATION IN A NONLINEAR SYSTEM
#
# Gauss Newtons method follows to obtained or estimate parameters.
#
# ### Qus: Where you can use newton guass method to estimate parameter?
#
# ![image-18.png](attachment:image-18.png)
#
# If models contain exponent form in eqn then we can use this method. For example
#
# ![image-19.png](attachment:image-19.png)
#
# ### Qus: How to proceed?
#
# First ger parameter values by using Newton Gauss method for this models
#
# ![image-20.png](attachment:image-20.png)
#
# Please stud on this link or follow your note https://www.youtube.com/watch?v=C6DCtQjKkdY&t=16s
#
# Next step Solver Book Example 12.3 Pg 425 and focus on following points
# - Estimations of σ^2
# - asymptotic (large-sample) covariance matrix of the parameter vector θ ̂
# - standard errors of θ ̂
# - Graphical Perspective on Linearization
#
# ### Qus: write down another method to find PARAMETER ESTIMATION IN A NONLINEAR SYSTEM.
#
# TODO
