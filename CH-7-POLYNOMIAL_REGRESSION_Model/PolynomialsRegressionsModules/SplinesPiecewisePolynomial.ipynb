# %%
'''
7.2.2 Piecewise Polynomial Fitting (Splines)

Data Fitting: Polynomial Fitting and Splines, Part 1
https://www.youtube.com/watch?v=BqZXS3n75l0&t=12s

Data Fitting: Polynomial Fitting and Splines, Part 2
https://www.youtube.com/watch?v=WDM_BGijXEc&t=8s  

Data Fitting: Polynomial Fitting and Splines, Part 3
https://www.youtube.com/watch?v=CAOuDjSIZuo

Data Fitting: Polynomial Fitting and Splines, Part 4
https://www.youtube.com/watch?v=rtwOrZL02M0
'''
# Out:
# '\n7.2.2 Piecewise Polynomial Fitting (Splines)\n\nData Fitting: Polynomial Fitting and Splines, Part 1\nhttps://www.youtube.com/watch?v=BqZXS3n75l0&t=12s\n\nData Fitting: Polynomial Fitting and Splines, Part 2\nhttps://www.youtube.com/watch?v=WDM_BGijXEc&t=8s  \n\nData Fitting: Polynomial Fitting and Splines, Part 3\nhttps://www.youtube.com/watch?v=CAOuDjSIZuo\n\nData Fitting: Polynomial Fitting and Splines, Part 4\nhttps://www.youtube.com/watch?v=rtwOrZL02M0\n'

# %% [markdown]
# TODO
#
# Time Issue. Require more work on it
