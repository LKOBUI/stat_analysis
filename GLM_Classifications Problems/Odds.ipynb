# %% [markdown]
# Odds:
# In probability theory, odds provide a measure of the probability of a particular outcome.
#
# •	"X in Y" means that the probability is p = X / Y.
# •	"X to Y in favor" means that the probability is
# p = X / (X + Y).
# •	"X to Y against" means that the probability is
# p = Y / (X + Y).
#
# Given odds (in favor) as the ratio W:L (number of outcomes that are wins:number of outcomes that are losses), the odds in favor (as a number) of and odds against (as a number) oa can be computed by simply dividing, and are
#
# ![image.png](attachment:image.png)
#
# Example #1
#
# Qus: There are 5 pink marbles, 2 blue marbles, and 8 purple marbles. What are the odds in favor of picking a blue marble?
#
# Answer: The odds in favors of a blue marble are 2:13.
#         The odds in against of a blue marble are 13:2
#
# ![image-2.png](attachment:image-2.png)
# ![image-3.png](attachment:image-3.png)
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# # contingency table
#
# There is a close connection between the odds ratio in logistic regression and the 2 x 2 contingency table that is widely used in the analysis of categorical data.
# 2 x 2 contingency table where the categorical response variable represents the outcome (infected, not infected) for a group of patients treated with either an active drug or a placebo.
#
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)
# ![image-3.png](attachment:image-3.png)
# ![image-4.png](attachment:image-4.png)
