# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)
#
# ### Qus: Why we need to check Leverage & Influence ? however in model adequacy checking you have already checked outlier.
#
# Ans: Leverage & influence are the property of the outliers. Outlier, the location of points in x space is potentially
# important in determining the properties of the regression model. Remote points (Outlier) potentially have disproportionate impact on the parameter estimates, standard errors, predicted values, and model summary statistics.
# So following method will tell you how to analysis on outliers.
#
# ### LEVERAGE:
#
# LEVERAGE calculated from hat matrix. The hat matrix plays an important role in identifying influential observations
#
# ![image-3.png](attachment:image-3.png)
# ![image-4.png](attachment:image-4.png)
#
# ### vQus: how to proceed with leverage point ?
#
# Example 6.1 The Delivery Time Data
#
# Since p = 3 and n = 25, any point for which the hat diagonal h_ii  exceeds 2p/n = 2(3)/25 = 0.24 is a leverage point. This criterion would identify observations 9 and 22 as leverage
# points.
#
# ![image-5.png](attachment:image-5.png)
#
# So this is end up? No. You need to further analysis about this.
#
# ### Step 1: h_ii  exceeds 2p/n = 2(3)/25 = 0.24 is a leverage point. This criterion would identify observations 9 and 22 as leverage points.
#
# ### Step 2: Calculate scaled residuals. Mainly the studentized residuals and R-student
#
#
# scaled residuals not unusually large for observation 22 scaled residuals for point 9 are moderately large
#
# ### Step 3: parameter analysis on 9/22
# ![image-6.png](attachment:image-6.png)
# ![image-7.png](attachment:image-7.png)
# ![image-8.png](attachment:image-8.png)
#
# ### Step 4: log-likelihood analysis for 9 & 22 i.e. highly influence on the fitted model
#
# Read further

# %% [markdown]
# ### MEASURES OF INFLUENCE: COOK’S D (No Cutoff, Only Large value of coocks distance will conclude about point of influence)
#
# ### Qus: Where it come from ?
#
# To measuring influence it is desirable to consider both the location of the point in the x space and the response variable.
#
# ***Cook’s distance measure is a deletion diagnostic, that is, it measures the influence of the ith observation if it is removed from the sample.***
#
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)
# ![image-3.png](attachment:image-3.png)
# ![image-4.png](attachment:image-4.png)
# ![image-5.png](attachment:image-5.png)

# %% [markdown]
# #### Qus: Input 9 & 22 both are the Outlier. Only 9 will dramatically influence parameter coefficient. See below explanations how to select D9.
#
# ![image.png](attachment:image.png)
#
# ### MEASURES OF INFLUENCE: DFFITS AND DFBETAS
#
# ***Cook’s distance*** measure is a deletion diagnostic, that is, it
# measures the influence of the ith observation if it is removed from the sample.
#
# two other useful measures of deletion influence
#
# ![image-2.png](attachment:image-2.png)
# ![image-3.png](attachment:image-3.png)
#
# We may also investigate the deletion influence of the ith observation on the predicted or fitted value. This leads to the second diagnostic proposed by Belsley, Kuh, and Welsch:
#
# ![image-4.png](attachment:image-4.png)
#
# - If the data point is an outlier, then R-student will be large in Magnitude
# - if the data point has high leverage, hii will be close to unity.
#
# In either of these cases DFFITSi can be large.
#
# ### Qus: How the DFFITSi is affected by both leverage and prediction error
#
# - if hii  ≅ 0, the effect of R-student will be moderated.
#
# Similarly a near-zero R-student combined with a high leverage point could produce a small value of DFFITSi. Thus, DFFITSi is affected by both leverage and prediction error.
#
# ![image-5.png](attachment:image-5.png)
#
# Recommended cutoff values for DFFITSi and DFBETASj,I, are only guidelines, as it is very difficult to produce cutoffs that are correct for all cases. we recommend that the analyst utilize information about both what the diagnostic means and the application environment in selecting a cutoff.
#
# ### Qus: What method is involve to select cutoff?
#
# For example, ***if DFFITSi = 1.0***, say, we could translate this into actual response units to determine just how much y_i is affected by removing the ith observation.
#
# Then ***〖DFBETAS 〗_(i,j)***  could be used to see whether this observation is responsible for the significance (or perhaps non-significance) of particular coefficients or for changes of sign in a regression coefficient.
#
# Another use of ***〖DFBETAS 〗_(i,j)*** used to determine (by using the standard
# error of the coefficient) how much change in actual problem specific units a data point has on the regression coefficient.
#
# #### A MEASURE OF MODEL PERFORMANCE
#
# Get information about overall precision of estimation
#
# The diagnostics ***Di, DFBETASj,i, and DFFITSi*** provide insight about the effect of observations on the estimated coefficients β_j and fitted values. ***They do not provide any information about overall precision of estimatio***n.
#
# Use the determinant of the ***covariance matrix as a convenient scalar measure of precision***, called the generalized variance
#
# ![image-6.png](attachment:image-6.png)
#
# - if COVRATIOi > 1, the ith observation improves the precision of estimation,
# - if COVRATIOi < 1, inclusion of the ith point degrades precision.
#
# ![image-7.png](attachment:image-7.png)
#
# ![image-8.png](attachment:image-8.png)
