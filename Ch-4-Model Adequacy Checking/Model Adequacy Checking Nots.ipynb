# %% [markdown]
# Fitting of the linear regression model, estimation of parameters testing of hypothesis properties of the estimator
#
# 1.	The relationship between the study variable and explanatory variables is linear, at least approximately.
#   - The error term has zero mean.
#   - The error term has a constant variance.
#   - The errors are uncorrelated.
#   - The errors are normally distributed.
#
# Checking of the linear relationship between study and explanatory variables
#
# ![image.png](attachment:image.png)
#
# 2. Case of more than one explanatory variables
#
# - Present by the scatterplot
#    - display the scatterplots in the upper triangular part of the plot matrix.
#    - Mention the corresponding correlation coefficients in the lower triangular part of the matrix.
#
# See Below diagram, which matrix representations for multilinear regressions
#
# ![image-2.png](attachment:image-2.png)
#
# #### Qus: How you will draw if Models like below ?
#
# ![image-3.png](attachment:image-3.png)
#
# Residual analysis:
#
# - Residuals have zero mean
# - An approximate average variance of residuals
#
# ![image-4.png](attachment:image-4.png)
# ![image-5.png](attachment:image-5.png)
# ![image-6.png](attachment:image-6.png)
# ![image-7.png](attachment:image-7.png)
# ![image-8.png](attachment:image-8.png)
#
# #### Methods for scaling residuals:
#
# ### 1. Standardized residuals:
# ![image-9.png](attachment:image-9.png)
#
# ### 2.	Studentized residuals
#  - See your note
#
# ### PRESS residuals:
#
# ![image-10.png](attachment:image-10.png)
# ![image-11.png](attachment:image-11.png)
#
# These prediction errors are called **PRESS residuals** because they are used in computing the prediction error sum of squares. They are also called as **deleted residuals**.
#
# ![image-12.png](attachment:image-12.png)
#
# R2 for Prediction Based on PRESS The PRESS statistic can be used to compute an R2-like statistic for prediction
#
# ![image-13.png](attachment:image-13.png)
#
# ![image-14.png](attachment:image-14.png)
#
# ![image-15.png](attachment:image-15.png)
#
# ![image-16.png](attachment:image-16.png)
#
# ![image-17.png](attachment:image-17.png)
#
# ![image-18.png](attachment:image-18.png)
#
# ![image-19.png](attachment:image-19.png)
#
# ![image-20.png](attachment:image-20.png)
#
# ![image-21.png](attachment:image-21.png)

# %% [markdown]
# ### Normal probability plot (normal probability plots help in verifying the assumption of normal distribution):
#
# The assumption of normality of disturbances is very much needed for the validity of the results for testing of hypothesis, confidence intervals and prediction intervals.
#
# ### Qus: Why we Required to this?
#
# ***Small departures from normality may not affect the model significantly, but gross nonnormality is more dangerous.***
#
#
# If errors are coming from a distribution with ***thicker and heavier tails than normal***, then the least-squares fit may be sensitive to a small set of data.
#
# ***Heavy tailed error distribution*** **often generates outliers that “pull” the least-squares too much in their direction**. In such cases, other estimation techniques like **robust regression methods** should be considered.
#
#
# The normal probability plots is a plot of ordered standardized residuals versus normal scores.
#
# The normal scores are the cumulative probability.
#
# #### 1.	ideal normal probability plot:
#
# - This figure has an ideal normal probability plot. Points lie approximately on the straight line and indicate that the underlying distribution is normal.
#
# ![image.png](attachment:image.png)
#
# #### 2.	If distribution is heavy-tailed:
#
# This figure has sharp upward and downward curves at both extremes. This indicates that the underlying distribution is heavy-tailed, i.e., the tails of the underlying distribution are thicker than the tails of normal distribution.
#
# ![image-2.png](attachment:image-2.png)
#
# #### 3.	If underlying distribution is light-tailed:
#
# This figure has flattening at the extremes for the curves. This indicates that the underlying distribution is light-tailed, i.e., the tails of the underlying distribution are thinner than the tails of normal distribution.
#
# ![image-3.png](attachment:image-3.png)
#
# ### 4.	If the underlying distribution is positively skewed:
#
# This figure has a sharp change in the direction of the trend in an upward direction from the mid. This indicates that the underlying distribution is positively skewed.
#
# ![image-4.png](attachment:image-4.png)
#
# ### 5.	If underlying distribution is negatively skewed:
#
# This figure has a sharp change in the direction of the trend in the downward direction from the mid. This indicates that the underlying distribution is negatively skewed.
#
# ![image-5.png](attachment:image-5.png)

# %% [markdown]
# ### Plots of residuals against the fitted value:
#
# detecting several common types of model inadequacies.
# ![image.png](attachment:image.png)
#
# ### Plots of residuals against explanatory variable:
#
# TODO
#
# ### Plots of residuals in time sequence
#
# TODO
#
# ### Partial regression and partial residual plots:
#
# TODO

# %% [markdown]
# #### Method behind this:
#
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)
# ![image-3.png](attachment:image-3.png)
# ![image-4.png](attachment:image-4.png)
# ![image-5.png](attachment:image-5.png)
# ![image-6.png](attachment:image-6.png)
# ![image-7.png](attachment:image-7.png)

# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)
# ![image-3.png](attachment:image-3.png)
# ![image-4.png](attachment:image-4.png)
# ![image-5.png](attachment:image-5.png)
#
# https://online.stat.psu.edu/stat501/lesson/2/2.10
#
# https://jekel.me/2017/Lack-of-fit-test-linear-regression/
