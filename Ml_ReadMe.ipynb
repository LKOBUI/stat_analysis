# %% [markdown]
# ### Get Data set in state models:
#
# •	Download Dataset in panda’s form:
#       data = sm.datasets.longley.load_pandas()
#       df = data.data
# •	Get y (endog) & X (exog)
# - data.endog
# - data.endog
# •	Get Variable name in list
# - data.endog_name
# - data.exog_name
#
# •	Apply OLS method
#
# #### Method 1:
#
#       data.exog = sm.add_constant(data.exog, prepend=False)
#
#       y, x = data.endog, data.exog
#
#       res = sm.OLS(y, x).fit()
#
# #### Method 2:
#
#     Get y & X directly from Data frame
#
# 	y, X = dmatrices('Lottery ~ Literacy + Wealth + Region', data=df,
#                       return_type='dataframe')
#
#      We Don’t need to add const in X. dmatrices() do automatic.
#
#     res = sm.OLS(y, x).fit()
#
# •	To Add const use
#
#     X = sm.add_constant(X)
#
# ### OLS:
#
# Write fitted models’ equations:
#
# - mod = ols(formula="Lottery ~ Literacy + Wealth + Region", data=df)
# - res = mod.fit()
# - print(res.summary())
#
#
# #### Get Result Class:
#
# •	Get DoF
# - 'df_model'       Equivalent to number of regressor/Input
# - ‘df_resid'       n-samples
# - 'nobs'           numbs of observations [dfn = p-1, dfd = N-p]
#      where p is the number of groups + const and N is the total
#      number of subjects in all groups.
#
# #### Get Models Params
# - mse_model(MSr)   Mean squared error the regressor.
# - mse_resid(MSres) Mean squared error of the residuals.
# - mse_total         Total mean squared error.
# - ssr(SSres)         Sum of squared (whitened) residuals.
# - ess(SSr)          Sum of Square Regression
# - SST              total sum of square, ESS + SSR
#                  The total sum of squares quantifies how
#                  much the response varies — it has nothing
#                  to do with which predictors are in the
#                  model.
#
# #### Residuals analysis
# - resid             The residuals of the model.
# - resid_pearson     Residuals, normalized to have unit
#                   variance.
# - wresid            The residuals of the transformed/whitened
#                   regressand and regressor(s).
#
# #### Regression coefficient
#
# - params
#
# #### Regression predicted
#
# - predict
#
# #### Regression predicted
# - 'predict',
#
# #### F-Test
#
# - f_test
# - f_pvalue           The p-value of the F-statistic.
# - fittedvalues       The predicted values for the original
#                    (unwhitened) design.
# - fvalue             F-statistic of the fully specified
#                    model.
# ####	T-Stat:
# - tvalues            Return the t-statistic for a given
#                    parameter estimate.
# - use_t              Flag indicating to use the Student's
#                    distribution in inference.
# - 't_test',          Hypothesis test
# - 't_test_pairwise',
# - 'uncentered_tss',  Use in WLS
#
# ####	Regression P Val
# - 'pvalues',
# ####	R-Sqr
# - rsquared          R-squared of the model.
# - rsquared_adj      Adjusted R-squared.
# ####	Log-likelihood:
# -     llf                 Log-likelihood of model
# ####	Confidence Interval (CI)
# - 'conf_int',    Confidence interval for β
# - 'conf_int_el', Confidence interval Empirical Likelihood
# - el_test   Test single or joint hypotheses using Empirical
#             Likelihood.
# ####	Covariance
# - cov_HC0        Heteroscedasticity robust covariance matrix.
# - cov_HC1        Heteroscedasticity robust covariance matrix.
# - cov_HC2        Heteroscedasticity robust covariance matrix.
# - cov_HC3        Heteroscedasticity robust covariance matrix.
# - 'cov_kwds', 'cov_params', 'cov_type',
# - 'normalized_cov_params'
# ####	Compair test
# - 'compare_f_test',
# - 'compare_lm_test',
# - 'compare_lr_test',
# ####	STD standard errors
# - bse     The standard errors of the parameter estimates.
# - aic     Akaike's information criteria.
# - bic     Bayes' information criteria.
# ####	Eigenvals
# - Eigenvals
# ####	Get:
# - 'get_influence', 'get_prediction', 'get_robustcov_results',
# ####	Outlier:
# - 'outlier_test'
# ####	Miscellaneous:
# - centered_tss
# - condition_number
#      - 'diagn', 'el_test',
#      - 'info_criteria', 'initialize', 'k_constant',
#      - load
#      - remove_data
#      - 'save',
#      - 'scale', Use for scalling ???
#      - 'summary',
#      - 'summary2', ??
# #### W Test:
# - 'wald_test', 'wald_test_terms', 'wresid'

# %% [markdown]
# ### Do Some analysis:
#
# Calculate variance/covariance of coefficient i.e. also called estimator. Remember variance should be minimum
#
# var(β) = ???
#
# covar(β)
#
# statsmodels\regression\tests\test_cov.py
# Yet I am leaving this topic. Mostly use in Influence test.
#
# - Estimator of σ2:
#
#      (σ^2 ) ̂   = SSres/(n-2) = MSres (res stand for residuals)
#
#           = std of regressors
#             Keep small
#
# 	Testing the Regression Coefficients (Check significance)
#
# README:
#
# - F-score calculations:
#
# f_score = (res.ess/res.df_model)/(res.ssr/res.df_resid)
# from OLS you can get same value by res.fvalue
#
# - Get F-Score or value:
#      res.fvalue or you can use
#      f_score = (res.ess/res.df_model)/(res.ssr/res.df_resid)
#      now res.fvalue & f_score both have same value.
#
# Note : For rest analysis please visit :
#
#        [T state] (https://github.com/LKOBUI/stat_analysis/blob/main/TTT-T-Test-StateModels.ipynb)
#
#        [F State] https://github.com/LKOBUI/stat_analysis/blob/main/TTT_F_Test_Statemodels.ipynb
#
# ####	Noncentral f distribution
# You can check non central f distro effect when NULL hypothesis reject in F-test
# As per theory
# F0 > Fα,k,n-k-1 [Reject null hypothesis]
# In this case  F0 follow Noncentral f distribution.
#
# -	Extra sum square
# -	Constrained lest square estimators:
# -	Hat Matrix {X(X’X)^-1X’}:

# %% [markdown]
# #### `Models’ adequacy check:
#
# - Deal with R2 and R2adj:
#
# Keep both value Maximum [0,1]
# Change when we add regressor variable. So we need to check for which regressor variable R2 and R2adj are Increased.
#
# - Qus: What I learn till yet?
#
# ![image.png](attachment:image.png)
#
# #### Extra Sum of Square Or Sequential Sum of square:
#
# ![image-2.png](attachment:image-2.png)
#
# - **mse_model(MSr)**   Mean squared error the regressor.
# - **mse_resid(MSres)** Mean squared error of the residuals.
# - **mse_total**         Total mean squared error.
# - **ssr(SSres)**         Sum of squared (whitened) residuals.
# - **ess**(SSr)          Sum of Square Regression
# - **SST**              total sum of square, ESS + SSR
#                  The total sum of squares quantifies how
#                  much the response varies — it has nothing
#                  to do with which predictors are in the
#                       model.
#
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# #  Confidence Intervals
#
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ### List Of Essential Parameters
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# ## MULTICOLLINEARITY DIAGNOSTICS
#
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)
# ![image-3.png](attachment:image-3.png)
# ![image-4.png](attachment:image-4.png)

# %% [markdown]
# ### Method dealing with multicollinearity [Dark Math]
#
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ### Polynomial Regressions:
#
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ### Robust regressions analysis
#
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)
# ![image-3.png](attachment:image-3.png)
