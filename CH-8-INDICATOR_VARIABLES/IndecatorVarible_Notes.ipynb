# %% [markdown]
# In some situations it is necessary to use **qualitative** or **categorical variables** as predictor variables in regression. This is done through the use of **indicator variables**. Sometimes indicator variables are called **dummy variables**.
#
# ### Qus: How indicator variable work and what effects on regression line?
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ### Qus: Final Conclusions ?
#
# **hypothesis of significance of regression is rejected & both regressors x1 (rpm) and x2 (tool type) contribute to the model.**
#
# Since the observed value of **F0** has a **very small P value**, the hypothesis of significance of regression is rejected, and since the **t statistics for β1 and β2 have small P values**, we conclude that both regressors x1 (rpm) and x2 (tool type) contribute to the model.
#
# ### Qus: The 95% confidence interval on β2 what information given ?
#
# ![image.png](attachment:image.png)
#
# Therefore, we are 95% confident that changing from tool type A to tool type B increases the mean tool life by between 12.135 and 17.873 hours.
#
# ### Model adequacy checking:
#
# Plot of tool life y versus lathe speed x1 for tool types A and B.
#
# ![image-2.png](attachment:image-2.png)
#
# ![image-3.png](attachment:image-3.png)
#
# ![image-4.png](attachment:image-4.png)
# ![image-5.png](attachment:image-5.png)

# %% [markdown]
# ### Qus: What is two or more4 then two-line solutions? Why we approach for single line solutions? What is benefit of single line solutions ?
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Since two different regression lines are employed to model the relationship between tool life and lathe speed in above Example , we could have **initially fit two separate straight-line models instead of a single model with an indicator variable**.
#
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# straight-line model with intercept β0 + β2 and slope β1 + β3. Therefore, the parameter β2 reflects the change in the intercept associated with changing from tool type A to tool type B (the classes 0 and 1 for the indicator variable x2), and β3 indicates the change in the slope associated with changing from tool type A to tool type B.

# %% [markdown]
# ### Now we can use extra sum of square method to check hypotheses.
#
# #### Hypothesis test example:
#
# To test whether or not the two regression models are identical, we would test
#
# ![image.png](attachment:image.png)
#
# **If H0: β2 = β3 = 0 is not rejected**, this would imply that a single regression model can explain the relationship between tool life and lathe speed.
#
# To test that the two regression lines have a common slope but possibly different intercepts, the hypotheses are
#
# ![image-2.png](attachment:image-2.png)
#
# ### Extra sum of square test with single line model eqn:
#
# Note Not possible in multiple line regression models
#
# ### Test Example 1:
#
# To test the hypothesis that the two regression lines are identical (H0 : β2 = β3 = 0), use the statistic
#
# ![image-3.png](attachment:image-3.png)
#
# ![image-4.png](attachment:image-4.png)
#
# ![image-5.png](attachment:image-5.png)
#
# ### Example 8.3 An Indicator Variable with More Than Two Levels
#
# The four levels of this factor can be modeled by three indicator variables, x2, x3, and x4, defined as follows:
#
# ![image-6.png](attachment:image-6.png)
#
# ![image-7.png](attachment:image-7.png)
# ![image-8.png](attachment:image-8.png)

# %% [markdown]
# Again you get 4 different eqn with selecting different indicator variables. So what is issue with this models you can read explanations form book PG 492
#
# ### Now single line eqn with cross product:
#
# ![image.png](attachment:image.png)
#
# Now The four regression models corresponding to the four types of air conditioning systems are as follows from above eqn
#
# ![image-2.png](attachment:image-2.png)
#
# Example 8.5 Comparing Regression Models
# Letter Study…
#
# ### 8.2 COMMENTS ON THE USE OF INDICATOR VARIABLES
#
# #### 8.2.1 Indicator Variables versus Regression on Allocated Codes
#
# #### **Qus: What is this?**
#
# Another method of Indicator variable. Instead of using indicator variables use qualitative factor.
#
# Another approach to the treatment of a qualitative variable in regression is to measure the levels of the variable by an allocated code.  What is allocated code ?
#
# Recall Example 8.3 where indicator variable more then 2 where an electric utility is investigating the effect of size of house and type of air conditioning system on residential electricity consumption.
#
# Instead of using three indicator variables to represent the four levels of the qualitative factor type of air conditioning system, we could use one quantitative factor, x2, with the following allocated code:
#
# ![image-3.png](attachment:image-3.png)
#
# Now you can proceed with simple manner
#
# ![image-4.png](attachment:image-4.png)
#
# ### 8.3 REGRESSION APPROACH TO ANALYSIS OF VARIANCE
#
# The **analysis of variance** is a technique frequently used to analyze data from **planned** or **designed experiments**.
#
# Ordinarily **we do not recommend** that regression methods be used for analysis of variance because the specialized computing techniques are usually quite efficient. However, there are some
# analysis-of-variance situations, particularly those involving unbalanced designs, where the regression approach is helpful.
#
# This will explain **One-Way Analysis of Variance**.
#
# Have no idea we should use it of not in our deep learning.
# See when you need to study.
#
# ### **State Models Is Here:**
#
# https://www.statsmodels.org/stable/contrasts.html
